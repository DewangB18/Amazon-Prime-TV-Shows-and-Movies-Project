# %% [markdown]
# # **Project Name**  :- **Amazon Prime Tv Shows and Movies (EDA)**

# %% [markdown]
# ##### **Project Type**   : - EDA
# ##### **Contribution**    :- Individual
# ##### **Name** :- Dewang Bhonde

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In the era of **digital entertainment**, streaming platforms such as Amazon Prime Video have become major sources of movies, TV shows, and original productions. With a large and continuously growing content library, analyzing this data can provide valuable insights into **content trends, audience preferences, ratings, popularity, and global representation**. This project focuses on performing an **Exploratory Data Analysis (EDA)** of Amazon Prime Video content using two datasets: **titles.csv** and **credits.csv**.
#
# The **titles.csv dataset** contains important information such as **title, type, release year, genres, runtime, age certification, country, IMDb rating, IMDb votes, TMDB rating, and TMDB popularity**. The **credits.csv dataset** contains information about **actors, directors, and writers** associated with different titles. By combining these datasets, the project provides a comprehensive view of both the content available on Amazon Prime and the creative contributors behind it.
#
# ### STEP 1 — Data Collection & Preprocessing
#
# The project begins with **data collection, cleaning, and preprocessing**. The datasets are inspected for **missing values, duplicate records, incorrect data types, and inconsistent information**. After cleaning, the two datasets are merged using a common identifier. This creates a structured dataset suitable for further analysis and visualization.
#
# ### STEP 2 — Content Distribution Analysis
#
# The project analyzes the distribution of **Movies vs. TV Shows** to understand the overall composition of the Amazon Prime library. **Year-wise and decade-wise release trends** are studied to identify periods of growth and changes in content production. Runtime analysis is also performed to understand the typical duration of available content.
#
# ### STEP 3 — Genre Analysis
#
# **Genre analysis** helps identify the types of content most frequently available on the platform. Genres such as **Drama, Comedy, Thriller, Action, Documentary, and Romance** are analyzed based on their frequency. Their **IMDb and TMDB ratings** are also compared. Decade-wise genre analysis helps identify how content representation has changed over time.
#
# ### STEP 4 — Ratings & Popularity
#
# A major focus of the project is the analysis of **IMDb ratings, IMDb votes, TMDB ratings, and TMDB popularity**. The project examines rating distributions and relationships between different engagement metrics. **Correlation analysis and scatter plots** are used to study whether highly rated titles also receive greater audience attention. The analysis also identifies **highly rated, highly voted, and highly popular titles**.
#
# ### STEP 5 — Age Certification Analysis
#
# The project examines **age certifications** such as **G, PG, PG-13, R, TV-14, and TV-MA**. This analysis helps understand how content is distributed across different audience categories. The project also compares **average ratings across certifications** to identify differences in content reception.
#
# ### STEP 6 — Country-Wise Analysis
#
# The geographical distribution of Amazon Prime content is analyzed to understand its **global content diversity**. The project identifies major content-producing countries and compares **US and non-US contributions**. Country-wise average ratings can also be examined, while a **world map visualization** can provide a clear representation of international content distribution.
#
# ### STEP 7 — Cast & Crew Analysis
#
# Using **credits.csv**, the project studies the contribution of **actors, directors, and writers**. Frequently appearing creative contributors are identified based on their number of titles. Their associated content ratings can also be analyzed to explore patterns between **creative contribution and audience reception**.
#
# ### STEP 8 — Time-Based & Statistical Analysis
#
# The project performs **decade-wise analysis** of content growth, genres, ratings, and runtime. Statistical techniques such as **descriptive statistics, correlation analysis, and aggregation** are used to identify meaningful relationships within the data.
#
# ### STEP 9 — Data Visualization & Insights
#
# The results are presented through **bar charts, line charts, histograms, box plots, scatter plots, heatmaps, and geographical maps**. These visualizations make complex datasets easier to understand and help communicate important findings effectively.
#
# ###  Final Outcome
#
# Overall, this project provides a comprehensive analysis of Amazon Prime Video's content library by examining **content distribution, genres, ratings, popularity, certifications, countries, runtime, and cast/crew information**. The project demonstrates how **Python, Pandas, NumPy, Matplotlib, and Seaborn** can be used to transform raw entertainment data into meaningful insights. It provides a structured understanding of **how streaming content has evolved and how different content characteristics are represented across the platform**.

# %% [markdown]
# ![AMAZON PHOTO.png](data:image/png;base64,...)

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/DewangB18/Amazon-Prime-TV-Shows-and-Movies-Project.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This dataset was created to analyze all shows available on Amazon Prime Video, allowing us to extract valuable insights such as:
#
# Content Diversity: What genres and categories dominate the platform?
# Regional Availability: How does content distribution vary across different regions?
# Trends Over Time: How has Amazon Prime’s content library evolved?
# IMDb Ratings & Popularity: What are the highest-rated or most popular shows on the platform?
#
# By analyzing this dataset, businesses, content creators, and data analysts can uncover key trends that influence subscription growth, user engagement, and content investment strategies in the streaming industry.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The objective of this project is to analyze Amazon Prime’s content library to uncover insights that can support data-driven decision-making for content strategy. By examining trends in genres, ratings, release years, popularity, and cast/crew contributions, the goal is to identify what resonates most with audiences. This analysis will help in understanding viewer preferences, optimizing content acquisition or production, and enhancing customer satisfaction. Ultimately, the insights aim to support Amazon Prime in strengthening its competitive edge in the global streaming market.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
title_df = pd.read_csv('/titles.csv')

# %%
credit_df = pd.read_csv('/credits.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
title_df.head()

# %%
credit_df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
title_df.shape

# %%
credit_df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
title_df.info()

# %%
credit_df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
title_df.duplicated().sum()

# %%
credit_df.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
title_df.isnull().sum()

# %%
# Visualizing the missing values
credit_df.isnull().sum()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# After getting the first view and some basic investigation I have found that there are 9871 rows & 15 columns in title_df dataframe and 124235 rows & 5 columns in the credit_df dataframe. We also found for duplicated values and found 3 duplicate values in title_df dataframe & 56 duplictate values in credit_df dataframe. We also found for null values and found these number of null values respectively. description-119, age_certification-6487, seasons-8514, imdb_id-667, imdb_score-1021, imdb_votes-1031, tmdb_popularity-547, tmdb_score-2082, character-16287.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
title_df.columns

# %%
credit_df.columns

# %%
# Dataset Describe
title_df.describe()

# %%
credit_df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The project uses two datasets — titles.csv and credits.csv — containing detailed information about Amazon Prime content. The titles dataset includes variables such as title, type (Movie/Show), release_year, runtime, genres, age_certification, production_countries, imdb_score, and tmdb_popularity, which describe each piece of content’s characteristics and performance. The credits dataset provides information on the people involved in the content, including name, character, and role (Actor, Director, or Writer). Together, these variables allow for a comprehensive analysis of content distribution, quality, audience ratings, and the creative contributors behind Amazon Prime’s library.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
title_df.nunique()

# %%
credit_df.nunique()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
#Replacing NaN values with 'Not Rated' in the age_certification column
title_df['age_certification'].fillna('Not Rated', inplace=True)

#Filling null values with mean values in imdb score column
title_df['imdb_score'].fillna(title_df['imdb_score'].mean(), inplace=True)

#Dropping duplicate values from both title_df and credit_df
title_df.drop_duplicates(inplace=True)
credit_df.drop_duplicates(inplace=True)

#Merging title_df dataset and credit_df dataset using 'id' as primary key
merged_df = title_df.merge(credit_df, on='id', how='left')

#Creating a column for decade
title_df['decade'] = (title_df['release_year'] // 10) * 10

#Categorize runtime into Short, Medium, or Long
merged_df['runtime_category'] = ''
for i in range(len(merged_df)):
    if merged_df.loc[i, 'runtime'] < 30:
        merged_df.loc[i, 'runtime_category'] = 'Short'
    elif merged_df.loc[i, 'runtime'] <= 90:
        merged_df.loc[i, 'runtime_category'] = 'Medium'
    else:
        merged_df.loc[i, 'runtime_category'] = 'Long'

#Add column is_movie (1 if movie, 0 if show)
merged_df['is_movie'] = 0
for i in range(len(merged_df)):
    if merged_df.loc[i, 'type'] == 'MOVIE':
        merged_df.loc[i, 'is_movie'] = 1
    else:
        merged_df.loc[i, 'is_movie'] = 0

# %%
#Categorize IMDb ratings (Poor, Average, Good, Excellent)
merged_df['rating_category'] = ''
for i in range(len(merged_df)):
    score = merged_df.loc[i, 'imdb_score']
    if pd.isna(score):
        merged_df.loc[i, 'rating_category'] = 'Not Rated'
    elif score < 5:
        merged_df.loc[i, 'rating_category'] = 'Poor'
    elif score < 7:
        merged_df.loc[i, 'rating_category'] = 'Average'
    elif score < 8.5:
        merged_df.loc[i, 'rating_category'] = 'Good'
    else:
        merged_df.loc[i, 'rating_category'] = 'Excellent'

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I performed data cleaning by handling missing values and duplicates, merged the titles and credits datasets using id, and created derived features such as decade, runtime category, is_movie, and IMDb rating category. These manipulations helped me analyze movie and TV-show distribution, content growth over time, runtime patterns, rating distribution, genre trends, audience engagement, geographical diversity, and cast and crew contributions.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ## **Chart 1 :- Movies vs TV Shows Count**

# %%
# Movies vs Shows

merged_df['type'].value_counts().plot(kind='bar', color=['skyblue', 'orange'])
plt.title('Movies vs Shows on Amazon Prime')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Bar chart is easy to understand.
# - It clearly compares Movies vs TV Shows.
# - It makes the difference in content count visible.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Shows the number of Movies and TV Shows.
# - Identifies which content type is more prevalent.
# - Helps understand the overall content distribution.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, it helps in content planning and investment decisions.
# Supports better content diversification.
# - Lower representation of one type can indicate an opportunity for expansion.
# - It does not directly indicate negative growth without additional time-based evidence.

# %% [markdown]
# ## **Chart 2 :- Releases by Year**

# %%
# Releases by Year

merged_df['release_year'].value_counts().sort_index().plot(kind='line', color='green')
plt.title('Content Released per Year')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Line chart is used to show the trend of content releases over different years.
# - It makes it easy to identify increases, decreases, and peak years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The chart shows how the number of titles released changes year by year.
# - A rising trend indicates increasing content production, while a decline indicates fewer releases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, it helps identify years with high content production and supports content planning and investment decisions.
# - Negative growth insight: A decline in recent releases may indicate reduced content availability, which could affect viewer engagement and retention.

# %% [markdown]
# ## **Chart 3 :- Runtime Distribution**

# %%
# Runtime Distribution

plt.hist(merged_df['runtime'].dropna(), bins=30, color='purple', edgecolor='black')
plt.title('Distribution of Movie Runtimes')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Histogram is used to show the distribution of movie runtimes.
# - It helps identify the most common movie duration range.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Most movies are concentrated within a specific runtime range.
# - Very short or very long movies appear less frequently.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, it helps understand viewer preferences and plan suitable content durations.
# - Negative insight: If very long movies are less common, producing too many long-duration movies may lead to lower viewer interest and engagement.

# %% [markdown]
# #### **Chart  4 :- IMDb Score Distribution**

# %%
# IMDb Score Distribution

sns.histplot(merged_df['imdb_score'], bins=20, kde=True, color='blue')
plt.title('Distribution of IMDb Scores')
plt.xlabel('IMDb Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Histogram with KDE is used to show the distribution of IMDb scores.
# - It helps identify the most common rating range.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Most titles are concentrated around a particular IMDb score range.
# - Very high or very low-rated titles occur less frequently.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, it helps identify content quality and viewer preferences for better content selection.
# - Negative insight: A high number of low-rated titles may indicate lower content quality, which can reduce viewer satisfaction and engagement.

# %% [markdown]
# #### **Chart 5 :- IMDb vs TMDB Correlation Scatterplot**

# %%
# IMDb vs TMDB Correlation Scatterplot

sns.scatterplot(data=merged_df, x='imdb_score', y='tmdb_score', color='orange')
plt.title('IMDb vs TMDB Score Correlation')
plt.xlabel('IMDb Score')
plt.ylabel('TMDB Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Scatter plot is used to show the relationship between IMDb and TMDB scores.
# - It helps identify whether the two ratings have a positive or negative correlation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The points generally show the relationship between IMDb and TMDB ratings.
# - If points move upward together, it indicates a positive correlation between the scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, it helps compare audience ratings across platforms and understand content quality.
# - Negative insight: If the correlation is weak, the two platforms may show different audience opinions, making rating-based content decisions less reliable.

# %% [markdown]
# #### **Chart 6 :- 10 Sort dataset by IMDb score (descending)**

# %%
# Sort dataset by IMDb score (descending)
top_rated = merged_df.sort_values('imdb_score', ascending=False).head(10)

# Create barplot for Top 10 Highest Rated Titles
plt.figure(figsize=(10,6))
sns.barplot(data=top_rated, x='imdb_score', hue='title', palette='coolwarm')

# Chart labels and title
plt.title('Top 10 Highest Rated Titles on Amazon Prime', fontsize=14, weight='bold')
plt.xlabel('IMDb Score', fontsize=12)
plt.ylabel('Title', fontsize=12)

# Display the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Bar chart is used to compare the IMDb scores of the Top 10 highest-rated titles.
# - It makes the ranking and score differences easy to understand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The chart identifies the Top 10 highest-rated titles based on IMDb scores.
# - These titles represent high-rated and potentially popular content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, it helps identify high-quality content for recommendations and content strategy.
# - Negative insight: If the platform has very few highly rated titles, it may indicate a limited supply of top-quality content, which could affect viewer satisfaction and retention.

# %% [markdown]
# #### **Chart 7 :- Certification Distribution**

# %%
# Certification Distribution

merged_df['age_certification'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.legend(title='Age Certification', loc='best')
plt.title('Distribution by Age Certification')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Pie chart is used to show the percentage distribution of age certifications.
# - It makes the share of each certification category easy to compare.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The chart shows which age certification categories have the highest and lowest share.
# - It helps understand the target audience distribution of the content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, it helps in content planning and audience targeting based on age groups.
# - Negative insight: If some age categories have very low content, the platform may have limited audience coverage, reducing opportunities to attract those viewers.

# %% [markdown]
# #### **Chart 8 :- IMDb Votes Trend**

# %%
# IMDb Votes Trend (if available)

if 'imdb_votes' in merged_df.columns:
    merged_df.groupby('release_year')['imdb_votes'].mean().plot(kind='line', color='blue')
    plt.title('Average IMDb Votes per Year')
    plt.xlabel('Year')
    plt.ylabel('Average Votes')
    plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Line chart is used to show the year-wise trend of average IMDb votes.
# - It clearly shows increases and decreases in viewer engagement over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Higher average votes indicate greater audience engagement and visibility.
# - A rising trend suggests increasing viewer interest in the content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, it helps identify periods of high audience engagement for better content planning.
# - Negative insight: A decline in average IMDb votes may indicate lower audience engagement, which can affect content visibility and viewer interest.

# %% [markdown]
# #### **Chart 9 :- Total Releases per Year**

# %%
# Total Releases per Year

merged_df['release_year'].value_counts().sort_index().plot(kind='line', color='darkred')
plt.title('Number of Releases Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Line chart is used to show the trend in total releases over the years.
# - It clearly shows increases and decreases in content production.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The chart shows how the number of titles released changes year by year.
# - A rising trend indicates increased content production, while a decline indicates fewer releases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, it helps in content planning, investment, and identifying high-production periods.
# - Negative insight: A decline in releases may indicate reduced content availability, which can affect viewer engagement and retention.

# %% [markdown]
# #### **Chart 10  :- Average IMDb Score by Year**

# %%
# Chart 10: Average IMDb Score by Year

avg_imdb_year = merged_df.groupby('release_year')['imdb_score'].mean()

plt.figure(figsize=(12,6))
avg_imdb_year.plot(kind='line', marker='o')

plt.title('Average IMDb Score by Release Year')
plt.xlabel('Release Year')
plt.ylabel('Average IMDb Score')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Line chart is suitable for showing trends over time.
# - It clearly shows how average IMDb ratings change year by year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - It Shows the trend in average IMDb scores over the years.
# - It Helps identify years with higher or lower average ratings.
# - They Shows whether the average rating is generally increasing or decreasing.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, it can help in content quality analysis and content planning.
# - Higher-rated periods can help identify successful content trends.
# - Negative growth insight:
# If the chart shows a continuous decline in average IMDb score, it may indicate decreasing audience satisfaction or weaker-rated content.

# %% [markdown]
# #### **Chart 11 :- Runtime Category vs Content Type**

# %%
# Chart 11: Runtime Category vs Content Type

runtime_type = pd.crosstab(
    merged_df['runtime_category'],
    merged_df['type']
)

runtime_type.plot(kind='bar', figsize=(10,6))

plt.title('Runtime Category by Content Type')
plt.xlabel('Runtime Category')
plt.ylabel('Number of Titles')
plt.xticks(rotation=0)
plt.legend(title='Content Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Bar chart is easy to understand and compare.
# - It clearly shows the relationship between runtime category and content type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - It Shows the number of Short, Medium, and Long titles for Movies and TV Shows.
# - It Helps identify which runtime category is most common for each content type.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, it helps in content planning and audience preference analysis.
# - Helps decide the suitable content duration for Movies and TV Shows.
# - Negative growth insight:
# If a particular runtime category has very low representation, it may indicate limited content in that format.

# %% [markdown]
# #### **Chart 12 :- TMDB Popularity vs IMDb Votes**

# %%
# Chart 12: TMDB Popularity vs IMDb Votes

plt.figure(figsize=(10,6))

sns.scatterplot(
    data=merged_df,
    x='tmdb_popularity',
    y='imdb_votes',
    alpha=0.5
)

plt.title('TMDB Popularity vs IMDb Votes')
plt.xlabel('TMDB Popularity')
plt.ylabel('IMDb Votes')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Scatter plot is suitable for showing the relationship between two numerical variables.
# - It helps identify whether TMDB popularity and IMDb votes are related.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Shows the relationship between TMDB popularity and audience engagement (IMDb votes).
# - Helps identify whether highly popular titles receive more IMDb votes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, it helps understand audience engagement and content popularity.
# - Can support content promotion and marketing decisions.
# - Negative growth insight:
# If highly popular titles have low IMDb votes, it may indicate lower audience engagement.

# %% [markdown]
# #### **Chart 13 :- Average IMDb Score by Content Type**

# %%
# Chart 13: Average IMDb Score by Content Type

avg_score_type = merged_df.groupby('type')['imdb_score'].mean()

plt.figure(figsize=(8,5))
avg_score_type.plot(kind='bar')

plt.title('Average IMDb Score by Content Type')
plt.xlabel('Content Type')
plt.ylabel('Average IMDb Score')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Bar chart is simple and easy to compare.
# - It clearly compares the average IMDb score of Movies and TV Shows.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Shows the average IMDb rating for Movies and TV Shows.
# - Helps identify which content type has a higher average rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, it helps in content quality analysis and planning.
# - Supports decisions about Movie vs TV Show content strategy.
# - Negative growth insight:
# If one content type has a consistently lower average IMDb score, it may indicate comparatively lower-rated content.

# %% [markdown]
# #### **Chart 14 :- Correlation Heatmap**

# %%
# Chart 14: Correlation Heatmap

numeric_columns = [
    'release_year',
    'runtime',
    'imdb_score',
    'imdb_votes',
    'tmdb_popularity',
    'tmdb_score'
]

correlation = merged_df[numeric_columns].corr()

plt.figure(figsize=(10,7))

sns.heatmap(
    correlation,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Heatmap is useful for showing relationships between multiple numerical variables.
# - It makes positive and negative correlations easy to identify

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Shows the correlation between IMDb score, IMDb votes, TMDB score, TMDB popularity, runtime, and release year.
# - Helps identify which variables have strong or weak relationships.
# - Values closer to +1 or -1 indicate stronger relationships.

# %% [markdown]
# #### **Chart 15 :- Pair Plot**

# %%
# Chart 15: Pair Plot

pair_columns = [
    'imdb_score',
    'imdb_votes',
    'tmdb_score',
    'tmdb_popularity',
    'runtime'
]

sns.pairplot(
    merged_df[pair_columns].dropna()
)

plt.suptitle(
    'Pairwise Relationships Between Numerical Variables',
    y=1.02
)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# - Pair plot shows relationships between multiple numerical variables at the same time.
# - It helps easily identify patterns, trends, and correlations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Shows relationships between IMDb score, IMDb votes, TMDB score, TMDB popularity, and runtime.
# - Helps identify variables with strong or weak relationships.
# - Also helps detect outliers and unusual data points.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. **Focus on Popular Genres & Regions** – Invest in and promote content from the most popular genres and regions identified through data analysis.
#
# 2. **Improve Audience Engagement** – Collaborate with successful **directors and actors** and invest in high-performing content categories.
#
# 3. **Personalized Recommendations** – Use **IMDb and TMDB ratings** to understand viewer preferences and improve personalized content recommendations.
#
# 4. **Maintain Content Balance** – Maintain a balance between **new releases and classic titles** to attract different audience groups.
#
# 5. **Business Impact** – These data-driven strategies can help **improve customer retention, optimize content strategy, and strengthen Amazon Prime’s position** in the global streaming market.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. **Key Insights:** The EDA identified important patterns in **genre popularity, release trends, content type, and IMDb/TMDB ratings**.
#
# 2. **Audience Understanding:** Analysis of ratings and regional contributions helps understand **audience preferences and content performance**.
#
# 3. **Business Opportunities:** These insights can support **better content investment, audience targeting, and content strategy**.
#
# 4. **Expected Impact:** A data-driven approach can help improve **viewer satisfaction, customer retention, and competitive positioning**.
#
# 5. **Overall Conclusion:** The project demonstrates how **data analytics can support informed business decisions** in the rapidly changing streaming industry.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
